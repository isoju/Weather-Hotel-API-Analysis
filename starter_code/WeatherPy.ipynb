# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "../output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
     
# Print the city count to confirm sufficient count
city_len = len(cities)
city_len
# Out:
# 605

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
#base url
weather_url = "http://api.openweathermap.org/data/2.5/weather?"
units = 'imperial'

#making lists for future dataframe
#made a new cities list in order to not count the ones that have no data
max_temp = []
humidity = []
cloudiness = []
wind_speed = []
country = []
date = []
lat = []
lng = []
new_cities = []

#setting indexes to print
set_count = 1
record_count = 0

print(f"Beginning Data Retrieval")
print(f"---------------------------------------------------")
for city in cities:
    try:
        weather_query = weather_url + "appid=" + weather_api_key +"&units="+ units + "&q=" + city
        weather_response = requests.get(weather_query).json()
        max_temp.append(weather_response['main']['temp_max'])
        humidity.append(weather_response['main']['humidity'])
        cloudiness.append(weather_response['clouds']['all'])
        wind_speed.append(weather_response['wind']['speed'])
        country.append(weather_response['sys']['country'])
        date.append(weather_response['dt'])
        lat.append(weather_response['coord']['lat'])
        lng.append(weather_response['coord']['lon'])
        new_cities.append(weather_response['name'])
        
        if record_count > 49:
            record_count = 0
            set_count += 1
        else:
            record_count += 1
            
        print(f"Processing Record {city_index} of Set {set_index} | {city}")
        
    except:
        print(f"City not found. Skipping...")
print(f"----------------------------------------------------")
print(f"Data Retrieval Complete")
print(f"----------------------------------------------------")
# Out:
# Beginning Data Retrieval
# ---------------------------------------------------
# City not found. Skipping...
# Processing Record 1 of Set 1 | victoria
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | kedrovyy
# Processing Record 4 of Set 1 | khatanga
# Processing Record 5 of Set 1 | salinas
# Processing Record 6 of Set 1 | puerto ayora
# Processing Record 7 of Set 1 | busselton
# Processing Record 8 of Set 1 | mataura
# Processing Record 9 of Set 1 | punta arenas
# Processing Record 10 of Set 1 | kapaa
# Processing Record 11 of Set 1 | ushuaia
# Processing Record 12 of Set 1 | hilo
# City not found. Skipping...
# Processing Record 13 of Set 1 | seybaplaya
# City not found. Skipping...
# Processing Record 14 of Set 1 | lagoa
# Processing Record 15 of Set 1 | kazachinskoye
# City not found. Skipping...
# Processing Record 16 of Set 1 | caravelas
# Processing Record 17 of Set 1 | new norfolk
# Processing Record 18 of Set 1 | chokurdakh
# Processing Record 19 of Set 1 | nuuk
# Processing Record 20 of Set 1 | orissaare
# Processing Record 21 of Set 1 | saldanha
# Processing Record 22 of Set 1 | bathsheba
# Processing Record 23 of Set 1 | alekseyevsk
# Processing Record 24 of Set 1 | airai
# Processing Record 25 of Set 1 | provideniya
# Processing Record 26 of Set 1 | wad rawah
# Processing Record 27 of Set 1 | luganville
# Processing Record 28 of Set 1 | maldonado
# Processing Record 29 of Set 1 | iskateley
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | half moon bay
# Processing Record 32 of Set 1 | butaritari
# Processing Record 33 of Set 1 | bengkulu
# Processing Record 34 of Set 1 | atuona
# Processing Record 35 of Set 1 | asau
# Processing Record 36 of Set 1 | yar-sale
# Processing Record 37 of Set 1 | bireun
# Processing Record 38 of Set 1 | coahuayana
# City not found. Skipping...
# Processing Record 39 of Set 1 | tuatapere
# Processing Record 40 of Set 1 | katsuura
# Processing Record 41 of Set 1 | albany
# Processing Record 42 of Set 1 | mildura
# Processing Record 43 of Set 1 | hermanus
# Processing Record 44 of Set 1 | ust-nera
# Processing Record 45 of Set 1 | kayerkan
# Processing Record 46 of Set 1 | vila velha
# Processing Record 47 of Set 1 | egvekinot
# Processing Record 48 of Set 1 | oxelosund
# Processing Record 49 of Set 1 | tiksi
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 0 of Set 2 | tasiilaq
# Processing Record 1 of Set 2 | qaanaaq
# Processing Record 2 of Set 2 | kolokani
# City not found. Skipping...
# Processing Record 3 of Set 2 | bandarbeyla
# City not found. Skipping...
# Processing Record 4 of Set 2 | malm
# Processing Record 5 of Set 2 | faya
# Processing Record 6 of Set 2 | hobart
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 7 of Set 2 | chumikan
# Processing Record 8 of Set 2 | georgetown
# Processing Record 9 of Set 2 | karera
# Processing Record 10 of Set 2 | naze
# Processing Record 11 of Set 2 | nampula
# Processing Record 12 of Set 2 | te anau
# Processing Record 13 of Set 2 | gamba
# Processing Record 14 of Set 2 | carlsbad
# Processing Record 15 of Set 2 | mar del plata
# Processing Record 16 of Set 2 | hithadhoo
# Processing Record 17 of Set 2 | mingaora
# Processing Record 18 of Set 2 | mandan
# Processing Record 19 of Set 2 | vila franca do campo
# Processing Record 20 of Set 2 | nikolskoye
# City not found. Skipping...
# Processing Record 21 of Set 2 | virginia beach
# Processing Record 22 of Set 2 | cape town
# Processing Record 23 of Set 2 | carnarvon
# Processing Record 24 of Set 2 | saint-philippe
# Processing Record 25 of Set 2 | jamestown
# City not found. Skipping...
# Processing Record 26 of Set 2 | port alfred
# Processing Record 27 of Set 2 | lebu
# Processing Record 28 of Set 2 | mahibadhoo
# Processing Record 29 of Set 2 | meulaboh
# Processing Record 30 of Set 2 | cubuk
# Processing Record 31 of Set 2 | marsh harbour
# Processing Record 32 of Set 2 | east london
# Processing Record 33 of Set 2 | ponazyrevo
# Processing Record 34 of Set 2 | cap-aux-meules
# Processing Record 35 of Set 2 | port-gentil
# Processing Record 36 of Set 2 | kloulklubed
# Processing Record 37 of Set 2 | namatanai
# Processing Record 38 of Set 2 | saint-augustin
# Processing Record 39 of Set 2 | ossora
# Processing Record 40 of Set 2 | dikson
# City not found. Skipping...
# Processing Record 41 of Set 2 | baoying
# Processing Record 42 of Set 2 | yellowknife
# Processing Record 43 of Set 2 | qasigiannguit
# Processing Record 44 of Set 2 | nchelenge
# Processing Record 45 of Set 2 | avarua
# Processing Record 46 of Set 2 | necochea
# Processing Record 47 of Set 2 | aklavik
# Processing Record 48 of Set 2 | shache
# Processing Record 49 of Set 2 | cabra
# Processing Record 50 of Set 2 | marystown
# Processing Record 0 of Set 3 | esperance
# Processing Record 1 of Set 3 | torbay
# Processing Record 2 of Set 3 | lazarev
# Processing Record 3 of Set 3 | barrow
# Processing Record 4 of Set 3 | beaverlodge
# Processing Record 5 of Set 3 | bardiyah
# Processing Record 6 of Set 3 | tautira
# Processing Record 7 of Set 3 | bambous virieux
# Processing Record 8 of Set 3 | bredasdorp
# Processing Record 9 of Set 3 | iqaluit
# Processing Record 10 of Set 3 | lavrentiya
# Processing Record 11 of Set 3 | cabo san lucas
# Processing Record 12 of Set 3 | katangli
# Processing Record 13 of Set 3 | sistranda
# Processing Record 14 of Set 3 | ribeira grande
# Processing Record 15 of Set 3 | wau
# Processing Record 16 of Set 3 | arandis
# Processing Record 17 of Set 3 | san rafael
# Processing Record 18 of Set 3 | ilulissat
# Processing Record 19 of Set 3 | canilla
# City not found. Skipping...
# Processing Record 20 of Set 3 | thompson
# Processing Record 21 of Set 3 | wunstorf
# Processing Record 22 of Set 3 | castro
# Processing Record 23 of Set 3 | bluff
# Processing Record 24 of Set 3 | eureka
# Processing Record 25 of Set 3 | kudahuvadhoo
# Processing Record 26 of Set 3 | scarborough
# Processing Record 27 of Set 3 | suna
# Processing Record 28 of Set 3 | coihaique
# City not found. Skipping...
# Processing Record 29 of Set 3 | laguna
# Processing Record 30 of Set 3 | villany
# City not found. Skipping...
# Processing Record 31 of Set 3 | fare
# Processing Record 32 of Set 3 | tamandare
# Processing Record 33 of Set 3 | hambantota
# Processing Record 34 of Set 3 | nanortalik
# Processing Record 35 of Set 3 | la libertad
# Processing Record 36 of Set 3 | diu
# Processing Record 37 of Set 3 | cartagena
# Processing Record 38 of Set 3 | paamiut
# Processing Record 39 of Set 3 | arraial do cabo
# Processing Record 40 of Set 3 | yumen
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 41 of Set 3 | flagstaff
# Processing Record 42 of Set 3 | pisco
# Processing Record 43 of Set 3 | pevek
# Processing Record 44 of Set 3 | yerbogachen
# Processing Record 45 of Set 3 | halmstad
# City not found. Skipping...
# Processing Record 46 of Set 3 | bururi
# Processing Record 47 of Set 3 | tifton
# City not found. Skipping...
# Processing Record 48 of Set 3 | hasaki
# Processing Record 49 of Set 3 | minsk
# Processing Record 50 of Set 3 | camacha
# Processing Record 0 of Set 4 | ingham
# City not found. Skipping...
# Processing Record 1 of Set 4 | rorvik
# City not found. Skipping...
# Processing Record 2 of Set 4 | kununurra
# Processing Record 3 of Set 4 | moncton
# City not found. Skipping...
# Processing Record 4 of Set 4 | pangkalanbuun
# Processing Record 5 of Set 4 | evensk
# Processing Record 6 of Set 4 | uvira
# Processing Record 7 of Set 4 | tiarei
# Processing Record 8 of Set 4 | kodiak
# Processing Record 9 of Set 4 | saskylakh
# Processing Record 10 of Set 4 | mount isa
# Processing Record 11 of Set 4 | tilichiki
# Processing Record 12 of Set 4 | bonthe
# Processing Record 13 of Set 4 | sao miguel do araguaia
# Processing Record 14 of Set 4 | port-cartier
# Processing Record 15 of Set 4 | tambura
# Processing Record 16 of Set 4 | san francisco
# Processing Record 17 of Set 4 | leningradskiy
# City not found. Skipping...
# Processing Record 18 of Set 4 | solnechnyy
# City not found. Skipping...
# Processing Record 19 of Set 4 | srednekolymsk
# Processing Record 20 of Set 4 | ahipara
# Processing Record 21 of Set 4 | henties bay
# Processing Record 22 of Set 4 | bethel
# Processing Record 23 of Set 4 | norman wells
# Processing Record 24 of Set 4 | vardo
# Processing Record 25 of Set 4 | magadan
# Processing Record 26 of Set 4 | saint-pierre
# Processing Record 27 of Set 4 | waipawa
# Processing Record 28 of Set 4 | salalah
# Processing Record 29 of Set 4 | usak
# Processing Record 30 of Set 4 | valdivia
# Processing Record 31 of Set 4 | teya
# Processing Record 32 of Set 4 | chegdomyn
# Processing Record 33 of Set 4 | yaan
# Processing Record 34 of Set 4 | avera
# Processing Record 35 of Set 4 | launceston
# Processing Record 36 of Set 4 | souillac
# Processing Record 37 of Set 4 | trail
# Processing Record 38 of Set 4 | manjeshwar
# Processing Record 39 of Set 4 | dharchula
# Processing Record 40 of Set 4 | grindavik
# Processing Record 41 of Set 4 | port hardy
# Processing Record 42 of Set 4 | ratlam
# Processing Record 43 of Set 4 | berlevag
# Processing Record 44 of Set 4 | kaitangata
# Processing Record 45 of Set 4 | crotone
# Processing Record 46 of Set 4 | basco
# Processing Record 47 of Set 4 | tugulym
# Processing Record 48 of Set 4 | asfi
# Processing Record 49 of Set 4 | jacareacanga
# Processing Record 50 of Set 4 | shahr-e kord
# Processing Record 0 of Set 5 | mocuba
# City not found. Skipping...
# Processing Record 1 of Set 5 | zhangye
# Processing Record 2 of Set 5 | fairbanks
# Processing Record 3 of Set 5 | sao filipe
# Processing Record 4 of Set 5 | pampa
# City not found. Skipping...
# Processing Record 5 of Set 5 | kahului
# Processing Record 6 of Set 5 | mareeba
# Processing Record 7 of Set 5 | noumea
# City not found. Skipping...
# Processing Record 8 of Set 5 | pangoa
# Processing Record 9 of Set 5 | fortuna
# Processing Record 10 of Set 5 | san ignacio
# Processing Record 11 of Set 5 | port elizabeth
# City not found. Skipping...
# Processing Record 12 of Set 5 | sorong
# City not found. Skipping...
# Processing Record 13 of Set 5 | longyearbyen
# Processing Record 14 of Set 5 | kibala
# City not found. Skipping...
# Processing Record 15 of Set 5 | charters towers
# Processing Record 16 of Set 5 | hovd
# Processing Record 17 of Set 5 | birjand
# Processing Record 18 of Set 5 | gallup
# City not found. Skipping...
# Processing Record 19 of Set 5 | zaysan
# Processing Record 20 of Set 5 | los llanos de aridane
# Processing Record 21 of Set 5 | santa fe
# Processing Record 22 of Set 5 | fort-shevchenko
# Processing Record 23 of Set 5 | bilma
# Processing Record 24 of Set 5 | siocon
# Processing Record 25 of Set 5 | winnemucca
# Processing Record 26 of Set 5 | sigli
# Processing Record 27 of Set 5 | cidreira
# Processing Record 28 of Set 5 | northam
# Processing Record 29 of Set 5 | urdoma
# Processing Record 30 of Set 5 | qaqortoq
# Processing Record 31 of Set 5 | mount gambier
# Processing Record 32 of Set 5 | newport
# Processing Record 33 of Set 5 | kaiserslautern
# Processing Record 34 of Set 5 | imeni poliny osipenko
# Processing Record 35 of Set 5 | husavik
# Processing Record 36 of Set 5 | pangnirtung
# Processing Record 37 of Set 5 | port lincoln
# Processing Record 38 of Set 5 | wanning
# Processing Record 39 of Set 5 | guerrero negro
# Processing Record 40 of Set 5 | pahrump
# Processing Record 41 of Set 5 | clyde river
# Processing Record 42 of Set 5 | cairns
# Processing Record 43 of Set 5 | rapid city
# Processing Record 44 of Set 5 | bukachacha
# Processing Record 45 of Set 5 | severo-kurilsk
# Processing Record 46 of Set 5 | ouesso
# Processing Record 47 of Set 5 | lorengau
# Processing Record 48 of Set 5 | ulladulla
# Processing Record 49 of Set 5 | ancud
# Processing Record 50 of Set 5 | mirnyy
# Processing Record 0 of Set 6 | taunggyi
# Processing Record 1 of Set 6 | bowen
# Processing Record 2 of Set 6 | natal
# Processing Record 3 of Set 6 | katherine
# Processing Record 4 of Set 6 | matay
# Processing Record 5 of Set 6 | vestmannaeyjar
# Processing Record 6 of Set 6 | binga
# Processing Record 7 of Set 6 | saint george
# Processing Record 8 of Set 6 | dakar
# Processing Record 9 of Set 6 | mount pleasant
# Processing Record 10 of Set 6 | bijapur
# Processing Record 11 of Set 6 | tigil
# Processing Record 12 of Set 6 | urucara
# Processing Record 13 of Set 6 | cherskiy
# City not found. Skipping...
# Processing Record 14 of Set 6 | strezhevoy
# City not found. Skipping...
# Processing Record 15 of Set 6 | aberdeen
# Processing Record 16 of Set 6 | daugavpils
# Processing Record 17 of Set 6 | mahebourg
# Processing Record 18 of Set 6 | nador
# Processing Record 19 of Set 6 | haines junction
# Processing Record 20 of Set 6 | straumen
# City not found. Skipping...
# Processing Record 21 of Set 6 | mehamn
# Processing Record 22 of Set 6 | portland
# Processing Record 23 of Set 6 | babstovo
# Processing Record 24 of Set 6 | praia da vitoria
# Processing Record 25 of Set 6 | weilheim
# Processing Record 26 of Set 6 | stabat
# Processing Record 27 of Set 6 | banjar
# Processing Record 28 of Set 6 | saint-francois
# Processing Record 29 of Set 6 | karpogory
# Processing Record 30 of Set 6 | hamilton
# Processing Record 31 of Set 6 | aswan
# Processing Record 32 of Set 6 | college
# Processing Record 33 of Set 6 | asyut
# City not found. Skipping...
# Processing Record 34 of Set 6 | aquidauana
# Processing Record 35 of Set 6 | samarkand
# Processing Record 36 of Set 6 | sayyan
# Processing Record 37 of Set 6 | havelock
# Processing Record 38 of Set 6 | nakusp
# Processing Record 39 of Set 6 | ponta do sol
# Processing Record 40 of Set 6 | kaz
# Processing Record 41 of Set 6 | manaskent
# Processing Record 42 of Set 6 | bulawayo
# Processing Record 43 of Set 6 | helong
# Processing Record 44 of Set 6 | florianopolis
# Processing Record 45 of Set 6 | sovetskaya gavan
# City not found. Skipping...
# Processing Record 46 of Set 6 | kanker
# Processing Record 47 of Set 6 | canmore
# Processing Record 48 of Set 6 | upernavik
# Processing Record 49 of Set 6 | sitka
# Processing Record 50 of Set 6 | nome
# Processing Record 0 of Set 7 | olinda
# Processing Record 1 of Set 7 | yankton
# Processing Record 2 of Set 7 | camana
# Processing Record 3 of Set 7 | butajira
# City not found. Skipping...
# Processing Record 4 of Set 7 | richards bay
# Processing Record 5 of Set 7 | sur
# Processing Record 6 of Set 7 | kenai
# City not found. Skipping...
# Processing Record 7 of Set 7 | sao jose da coroa grande
# Processing Record 8 of Set 7 | hailar
# Processing Record 9 of Set 7 | ornskoldsvik
# Processing Record 10 of Set 7 | marica
# Processing Record 11 of Set 7 | mutis
# Processing Record 12 of Set 7 | baghdad
# Processing Record 13 of Set 7 | dowa
# Processing Record 14 of Set 7 | volosovo
# Processing Record 15 of Set 7 | verkhoyansk
# Processing Record 16 of Set 7 | bugasong
# Processing Record 17 of Set 7 | ambilobe
# Processing Record 18 of Set 7 | ucluelet
# Processing Record 19 of Set 7 | luderitz
# Processing Record 20 of Set 7 | vostok
# Processing Record 21 of Set 7 | baykit
# Processing Record 22 of Set 7 | talcahuano
# Processing Record 23 of Set 7 | zhicheng
# Processing Record 24 of Set 7 | seoul
# Processing Record 25 of Set 7 | mayumba
# Processing Record 26 of Set 7 | anadyr
# Processing Record 27 of Set 7 | jhabua
# Processing Record 28 of Set 7 | anchorage
# Processing Record 29 of Set 7 | cianorte
# Processing Record 30 of Set 7 | dingle
# Processing Record 31 of Set 7 | nipawin
# Processing Record 32 of Set 7 | karratha
# City not found. Skipping...
# Processing Record 33 of Set 7 | cayenne
# Processing Record 34 of Set 7 | xambioa
# Processing Record 35 of Set 7 | sisimiut
# Processing Record 36 of Set 7 | kuytun
# Processing Record 37 of Set 7 | banda aceh
# Processing Record 38 of Set 7 | marawi
# Processing Record 39 of Set 7 | casablanca
# Processing Record 40 of Set 7 | porto walter
# Processing Record 41 of Set 7 | sinazongwe
# Processing Record 42 of Set 7 | cockburn town
# Processing Record 43 of Set 7 | kulashi
# Processing Record 44 of Set 7 | valera
# Processing Record 45 of Set 7 | amahai
# Processing Record 46 of Set 7 | mantua
# Processing Record 47 of Set 7 | poum
# Processing Record 48 of Set 7 | bourail
# City not found. Skipping...
# Processing Record 49 of Set 7 | makueni
# Processing Record 50 of Set 7 | urut
# Processing Record 0 of Set 8 | watsa
# City not found. Skipping...
# Processing Record 1 of Set 8 | port blair
# Processing Record 2 of Set 8 | biak
# Processing Record 3 of Set 8 | da nang
# Processing Record 4 of Set 8 | taoudenni
# Processing Record 5 of Set 8 | privodino
# Processing Record 6 of Set 8 | ust-kuyga
# Processing Record 7 of Set 8 | mbuji-mayi
# Processing Record 8 of Set 8 | luau
# Processing Record 9 of Set 8 | nisia floresta
# Processing Record 10 of Set 8 | gwadar
# Processing Record 11 of Set 8 | bosaso
# Processing Record 12 of Set 8 | ambon
# Processing Record 13 of Set 8 | vilhena
# Processing Record 14 of Set 8 | turayf
# Processing Record 15 of Set 8 | itarema
# Processing Record 16 of Set 8 | ranong
# Processing Record 17 of Set 8 | geraldton
# Processing Record 18 of Set 8 | rock hill
# Processing Record 19 of Set 8 | acapulco
# Processing Record 20 of Set 8 | arman
# Processing Record 21 of Set 8 | gubkinskiy
# Processing Record 22 of Set 8 | adrar
# Processing Record 23 of Set 8 | harper
# City not found. Skipping...
# Processing Record 24 of Set 8 | zhigansk
# Processing Record 25 of Set 8 | balclutha
# Processing Record 26 of Set 8 | tiznit
# Processing Record 27 of Set 8 | tra vinh
# Processing Record 28 of Set 8 | lazaro cardenas
# Processing Record 29 of Set 8 | rawson
# Processing Record 30 of Set 8 | rongcheng
# Processing Record 31 of Set 8 | novobelokatay
# Processing Record 32 of Set 8 | tocopilla
# Processing Record 33 of Set 8 | sonoita
# Processing Record 34 of Set 8 | jalingo
# Processing Record 35 of Set 8 | cap malheureux
# Processing Record 36 of Set 8 | beringovskiy
# Processing Record 37 of Set 8 | beyneu
# Processing Record 38 of Set 8 | orotukan
# Processing Record 39 of Set 8 | nortelandia
# Processing Record 40 of Set 8 | vanimo
# Processing Record 41 of Set 8 | maneadero
# Processing Record 42 of Set 8 | kilembe
# Processing Record 43 of Set 8 | narsaq
# Processing Record 44 of Set 8 | yangambi
# Processing Record 45 of Set 8 | chuy
# Processing Record 46 of Set 8 | kruisfontein
# Processing Record 47 of Set 8 | parana
# Processing Record 48 of Set 8 | lasa
# Processing Record 49 of Set 8 | san patricio
# Processing Record 50 of Set 8 | fort nelson
# Processing Record 0 of Set 9 | lovozero
# Processing Record 1 of Set 9 | padang
# Processing Record 2 of Set 9 | oulainen
# Processing Record 3 of Set 9 | kidal
# Processing Record 4 of Set 9 | kavieng
# Processing Record 5 of Set 9 | careiro da varzea
# Processing Record 6 of Set 9 | comodoro rivadavia
# Processing Record 7 of Set 9 | lata
# Processing Record 8 of Set 9 | murray
# City not found. Skipping...
# Processing Record 9 of Set 9 | nagato
# Processing Record 10 of Set 9 | vangaindrano
# Processing Record 11 of Set 9 | usinsk
# Processing Record 12 of Set 9 | walvis bay
# Processing Record 13 of Set 9 | bonavista
# Processing Record 14 of Set 9 | thinadhoo
# Processing Record 15 of Set 9 | ambulu
# Processing Record 16 of Set 9 | santa cruz
# Processing Record 17 of Set 9 | dong xoai
# City not found. Skipping...
# Processing Record 18 of Set 9 | gobabis
# Processing Record 19 of Set 9 | auki
# Processing Record 20 of Set 9 | wasilla
# Processing Record 21 of Set 9 | preobrazheniye
# Processing Record 22 of Set 9 | beian
# Processing Record 23 of Set 9 | valentin gomez farias
# Processing Record 24 of Set 9 | antequera
# Processing Record 25 of Set 9 | katobu
# Processing Record 26 of Set 9 | ghugus
# Processing Record 27 of Set 9 | whyalla
# Processing Record 28 of Set 9 | kushiro
# Processing Record 29 of Set 9 | bell ville
# Processing Record 30 of Set 9 | adolfo lopez mateos
# Processing Record 31 of Set 9 | malartic
# Processing Record 32 of Set 9 | lixourion
# Processing Record 33 of Set 9 | puerto suarez
# Processing Record 34 of Set 9 | itupiranga
# Processing Record 35 of Set 9 | bontang
# Processing Record 36 of Set 9 | moose jaw
# City not found. Skipping...
# Processing Record 37 of Set 9 | cabudare
# Processing Record 38 of Set 9 | nuevo imperial
# Processing Record 39 of Set 9 | salta
# Processing Record 40 of Set 9 | panzhihua
# Processing Record 41 of Set 9 | lungi
# Processing Record 42 of Set 9 | goderich
# Processing Record 43 of Set 9 | concordia
# Processing Record 44 of Set 9 | snyder
# Processing Record 45 of Set 9 | wollongong
# Processing Record 46 of Set 9 | qiqihar
# Processing Record 47 of Set 9 | kargasok
# Processing Record 48 of Set 9 | brokopondo
# Processing Record 49 of Set 9 | tual
# Processing Record 50 of Set 9 | vestmanna
# Processing Record 0 of Set 10 | cabinda
# Processing Record 1 of Set 10 | payo
# Processing Record 2 of Set 10 | jacobina
# City not found. Skipping...
# Processing Record 3 of Set 10 | shetpe
# Processing Record 4 of Set 10 | torrelavega
# Processing Record 5 of Set 10 | flin flon
# Processing Record 6 of Set 10 | tura
# Processing Record 7 of Set 10 | puerto quijarro
# Processing Record 8 of Set 10 | abu dhabi
# Processing Record 9 of Set 10 | barcelos
# Processing Record 10 of Set 10 | atyrau
# Processing Record 11 of Set 10 | kalmunai
# Processing Record 12 of Set 10 | grand gaube
# Processing Record 13 of Set 10 | alofi
# Processing Record 14 of Set 10 | komsomolskiy
# Processing Record 15 of Set 10 | malaya serdoba
# Processing Record 16 of Set 10 | hami
# Processing Record 17 of Set 10 | piacenza
# Processing Record 18 of Set 10 | ostrovnoy
# Processing Record 19 of Set 10 | sechura
# Processing Record 20 of Set 10 | tela
# Processing Record 21 of Set 10 | jieshi
# Processing Record 22 of Set 10 | kattivakkam
# Processing Record 23 of Set 10 | mwinilunga
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 24 of Set 10 | isiro
# Processing Record 25 of Set 10 | puerto escondido
# Processing Record 26 of Set 10 | puerto colombia
# Processing Record 27 of Set 10 | san cristobal
# Processing Record 28 of Set 10 | kushima
# Processing Record 29 of Set 10 | pimentel
# Processing Record 30 of Set 10 | koungou
# Processing Record 31 of Set 10 | gusevskiy
# Processing Record 32 of Set 10 | faanui
# Processing Record 33 of Set 10 | mayo
# Processing Record 34 of Set 10 | amatan
# Processing Record 35 of Set 10 | bukama
# Processing Record 36 of Set 10 | eldorado
# Processing Record 37 of Set 10 | tateyama
# Processing Record 38 of Set 10 | cienaga
# Processing Record 39 of Set 10 | broome
# Processing Record 40 of Set 10 | clarksburg
# Processing Record 41 of Set 10 | namibe
# Processing Record 42 of Set 10 | gaya
# Processing Record 43 of Set 10 | tabou
# Processing Record 44 of Set 10 | guangyuan
# Processing Record 45 of Set 10 | qianguo
# Processing Record 46 of Set 10 | moorhead
# Processing Record 47 of Set 10 | cabedelo
# Processing Record 48 of Set 10 | yasnyy
# Processing Record 49 of Set 10 | soyo
# Processing Record 50 of Set 10 | camocim
# Processing Record 0 of Set 11 | stornoway
# Processing Record 1 of Set 11 | elizabeth city
# Processing Record 2 of Set 11 | yelizovo
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 3 of Set 11 | estremoz
# Processing Record 4 of Set 11 | sao joao da barra
# Processing Record 5 of Set 11 | asifabad
# Processing Record 6 of Set 11 | havre-saint-pierre
# Processing Record 7 of Set 11 | shakhovskaya
# Processing Record 8 of Set 11 | antofagasta
# Processing Record 9 of Set 11 | sao gabriel da cachoeira
# Processing Record 10 of Set 11 | mandali
# Processing Record 11 of Set 11 | axim
# Processing Record 12 of Set 11 | gambo
# Processing Record 13 of Set 11 | sao joao batista
# Processing Record 14 of Set 11 | mugur-aksy
# Processing Record 15 of Set 11 | roma
# Processing Record 16 of Set 11 | kirakira
# Processing Record 17 of Set 11 | saint anthony
# Processing Record 18 of Set 11 | kuching
# City not found. Skipping...
# Processing Record 19 of Set 11 | kilindoni
# Processing Record 20 of Set 11 | kasongo-lunda
# City not found. Skipping...
# Processing Record 21 of Set 11 | whangamata
# Processing Record 22 of Set 11 | tadine
# Processing Record 23 of Set 11 | ulan-ude
# Processing Record 24 of Set 11 | isangel
# Processing Record 25 of Set 11 | uchiza
# Processing Record 26 of Set 11 | bairiki
# Processing Record 27 of Set 11 | boo
# City not found. Skipping...
# Processing Record 28 of Set 11 | santo antonio do sudoeste
# Processing Record 29 of Set 11 | limulunga
# Processing Record 30 of Set 11 | presidencia roque saenz pena
# Processing Record 31 of Set 11 | maple creek
# Processing Record 32 of Set 11 | atasu
# Processing Record 33 of Set 11 | mbarara
# Processing Record 34 of Set 11 | ajdabiya
# City not found. Skipping...
# Processing Record 35 of Set 11 | klaksvik
# Processing Record 36 of Set 11 | erzin
# Processing Record 37 of Set 11 | maceio
# Processing Record 38 of Set 11 | altay
# Processing Record 39 of Set 11 | nha trang
# Processing Record 40 of Set 11 | pajapan
# Processing Record 41 of Set 11 | neryungri
# ----------------------------------------------------
# Data Retrieval Complete
# ----------------------------------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
#setting dataframe
weather_df = pd.DataFrame({'City':new_cities, 'Lat':lat, 'Lng':lng, 'Max Temp':max_temp, 
                           'Humidity':humidity, 'Cloudiness':cloudiness, 'Wind Speed':wind_speed, 
                           'Country':country, 'Date':date})
weather_df.head(-5)
# Out:
#           City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0    Hong Kong  22.2855  114.1577     88.97        83          58        7.00
# 1      Rikitea -23.1203 -134.9692     73.51        73           0       19.33
# 2     Kedrovyy  56.1667   91.8167     63.01        53           0        8.28
# 3     Khatanga  71.9667  102.5000     63.77        61         100        9.93
# 4      Salinas  36.6777 -121.6555     83.57        73          75       14.97
# ..         ...      ...       ...       ...       ...         ...         ...
# 541      Atasū  48.6814   71.6433     68.67        58           0        7.14
# 542    Mbarara  -0.6080   30.6500     63.81        57          56        2.84
# 543   Ajdabiya  30.7554   20.2263     75.83        75           0       10.63
# 544   Klaksvík  62.2266   -6.5890     47.32        93          92       10.42
# 545      Erzin  36.9559   36.2000     79.52        92          39        0.96
#
#     Country        Date
# 0        HK  1627003672
# 1        PF  1627003639
# 2        RU  1627003837
# 3        RU  1627003647
# 4        US  1627003541
# ..      ...         ...
# 541      KZ  1627003644
# 542      UG  1627003996
# 543      LY  1627003997
# 544      FO  1627003997
# 545      TR  1627003998
#
# [546 rows x 9 columns]

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
humidity_df = weather_df.loc(weather_df['Humidity']<= 100)
humidity_df.head(-5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-8-0e1dadc2e553> in <module>
# ----> 1 humidity_df = weather_df.loc(weather_df['Humidity']< 100)
#       2 humidity_df.head(-5)
#
# c:\users\andrew\appdata\local\programs\python\python39\lib\site-packages\pandas\core\indexing.py in __call__(self, axis)
#     605
#     606         if axis is not None:
# --> 607             axis = self.obj._get_axis_number(axis)
#     608         new_self.axis = axis
#     609         return new_self
#
# c:\users\andrew\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in _get_axis_number(cls, axis)
#     458     def _get_axis_number(cls, axis: Axis) -> int:
#     459         try:
# --> 460             return cls._AXIS_TO_AXIS_NUMBER[axis]
#     461         except KeyError:
#     462             raise ValueError(f"No axis named {axis} for object type {cls.__name__}")
#
# c:\users\andrew\appdata\local\programs\python\python39\lib\site-packages\pandas\core\generic.py in __hash__(self)
#    1783
#    1784     def __hash__(self) -> int:
# -> 1785         raise TypeError(
#    1786             f"{repr(type(self).__name__)} objects are mutable, "
#    1787             f"thus they cannot be hashed"
#
# TypeError: 'Series' objects are mutable, thus they cannot be hashed

# %%
#  Get the indices of cities that have humidity over 100%.

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
